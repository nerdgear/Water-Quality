# %%
#Load in zipfiles and extract 
import os
import glob
import zipfile


dir_name_base = "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021"

for arc_name in glob.iglob(os.path.join(dir_name_base, "*.zip")):
    arc_dir_name = os.path.splitext(os.path.basename(arc_name))[0]
    zf = zipfile.ZipFile(arc_name)
    zf.extractall(path=os.path.join(dir_name_base, "WQP_extract", arc_dir_name))
    zf.close() # close file after extraction is completed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-3487dea11a58> in <module>
#      10     arc_dir_name = os.path.splitext(os.path.basename(arc_name))[0]
#      11     zf = zipfile.ZipFile(arc_name)
# ---> 12     zf.extractall(path=os.path.join(dir_name_base, "WQP_extract", arc_dir_name))
#      13     zf.close() # close file after extraction is completed
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in extractall(self, path, members, pwd)
#    1645
#    1646         for zipinfo in members:
# -> 1647             self._extract_member(zipinfo, path, pwd)
#    1648
#    1649     @classmethod
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1699
#    1700         with self.open(member, pwd=pwd) as source, \
# -> 1701              open(targetpath, "wb") as target:
#    1702             shutil.copyfileobj(source, target)
# ...

# %%
#MISCELLANEOUS
#Filter for any string containing Stephen's Parameters
A= "NE_activitymetrics_bioregion_clipped.csv"
B= "NE_biological_habmetric_bioregion_clipped.csv"
C="NE_monitoringlocations_bioregion_clipped.csv"
D="NE_narrowresults_bioregion_clipped.csv"
E="NE_physchem_bioregion_clipped.csv"
F="NE_resdetectqntlmt_bioregion_clipped.csv"
G="NE_resultsbiological_bioregion_clipped.csv"
H="NE_sitedata_bioregion_clipped.csv"
I="SD_activitymetric_bioregion_clipped.csv"
J="SD_biohab_metric_bioregion_clipped.csv"
K="SD_monitoringlocations_bioregion_clipped.csv"
L="SD_narrowresults_bioregion_clipped.csv"
M="SD_physchemresults_bioregion_clipped.csv"
N="SD_resultsbiological_bioregion_clipped.csv"
O="SD_sitedata_bioregion_clipped.csv"


#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_activitymetrics_bioregion_clipped_misc.csv')) 


#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_biological_habmetric_bioregion_clipped_misc.csv')) 

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_monitoringlocations_bioregion_clipped_misc.csv')) 

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_narrowresults_bioregion_clipped_misc.csv')) 

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_physchem_bioregion_clipped_misc.csv')) 

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resdetectqntlmt_bioregion_clipped_misc.csv')) 

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resultsbiological_bioregion_clipped_misc.csv')) 

#H
df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_sitedata_bioregion_clipped_misc.csv')) 

#I
df = pd.read_csv(I, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_activitymetric_bioregion_clipped_misc.csv')) 

#J
df = pd.read_csv(J, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_biohab_metric_bioregion_clipped_misc.csv')) 

#K
df = pd.read_csv(K, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_monitoringlocations_bioregion_clipped_misc.csv')) 


#L
df = pd.read_csv(L, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_narrowresults_bioregion_clipped_misc.csv')) 

#M
df = pd.read_csv(M, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_physchemresults_bioregion_clipped_misc.csv'))

#N
df = pd.read_csv(N, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_resultsbiological_bioregion_clipped_misc.csv'))

#O
df = pd.read_csv(O, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_sitedata_bioregion_clipped_misc.csv'))
# Out:
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll

# %%
#MISCELLANEOUS
#Filter for any string containing Stephen's Parameters
A= "NE_activitymetrics_bioregion_clipped.csv"
B= "NE_biological_habmetric_bioregion_clipped.csv"
C="NE_monitoringlocations_bioregion_clipped.csv"
D="NE_narrowresults_bioregion_clipped.csv"
E="NE_physchem_bioregion_clipped.csv"
F="NE_resdetectqntlmt_bioregion_clipped.csv"
G="NE_resultsbiological_bioregion_clipped.csv"
H="NE_sitedata_bioregion_clipped.csv"
I="SD_activitymetric_bioregion_clipped.csv"
J="SD_biohab_metric_bioregion_clipped.csv"
K="SD_monitoringlocations_bioregion_clipped.csv"
L="SD_narrowresults_bioregion_clipped.csv"
M="SD_physchemresults_bioregion_clipped.csv"
N="SD_resultsbiological_bioregion_clipped.csv"
O="SD_sitedata_bioregion_clipped.csv"


#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_activitymetrics_bioregion_clipped_general.csv')) 


#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_biological_habmetric_bioregion_clipped_general.csv')) 

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_monitoringlocations_bioregion_clipped_general.csv')) 

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_narrowresults_bioregion_clipped_general.csv')) 

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_physchem_bioregion_clipped_general.csv')) 

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resdetectqntlmt_bioregion_clipped_general.csv')) 

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resultsbiological_bioregion_clipped_general.csv')) 

#H
df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_sitedata_bioregion_clipped_general.csv')) 

#I
df = pd.read_csv(I, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_activitymetric_bioregion_clipped_general.csv')) 

#J
df = pd.read_csv(J, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_biohab_metric_bioregion_clipped_general.csv')) 

#K
df = pd.read_csv(K, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_monitoringlocations_bioregion_clipped_general.csv')) 


#L
df = pd.read_csv(L, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_narrowresults_bioregion_clipped_general.csv')) 

#M
df = pd.read_csv(M, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_physchemresults_bioregion_clipped_general.csv'))

#N
df = pd.read_csv(N, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_resultsbiological_bioregion_clipped_general.csv'))

#O
df = pd.read_csv(O, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_sitedata_bioregion_clipped_general.csv'))
# Out:
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# ...

# %%
#Nutrients
#MISCELLANEOUS
#Filter for any string containing Stephen's Parameters
A= "NE_activitymetrics_bioregion_clipped.csv"
B= "NE_biological_habmetric_bioregion_clipped.csv"
C="NE_monitoringlocations_bioregion_clipped.csv"
D="NE_narrowresults_bioregion_clipped.csv"
E="NE_physchem_bioregion_clipped.csv"
F="NE_resdetectqntlmt_bioregion_clipped.csv"
G="NE_resultsbiological_bioregion_clipped.csv"
H="NE_sitedata_bioregion_clipped.csv"
I="SD_activitymetric_bioregion_clipped.csv"
J="SD_biohab_metric_bioregion_clipped.csv"
K="SD_monitoringlocations_bioregion_clipped.csv"
L="SD_narrowresults_bioregion_clipped.csv"
M="SD_physchemresults_bioregion_clipped.csv"
N="SD_resultsbiological_bioregion_clipped.csv"
O="SD_sitedata_bioregion_clipped.csv"


#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_activitymetrics_bioregion_clipped_nutrients.csv')) 


#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_biological_habmetric_bioregion_clipped_nutrients.csv')) 

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_monitoringlocations_bioregion_clipped_nutrients.csv')) 

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_narrowresults_bioregion_clipped_nutrients.csv')) 

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_physchem_bioregion_clipped_nutrients.csv')) 

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resdetectqntlmt_bioregion_clipped_nutrients.csv')) 

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_resultsbiological_bioregion_clipped_nutrients.csv')) 

#H
df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'NE_sitedata_bioregion_clipped_nutrients.csv')) 

#I
df = pd.read_csv(I, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_activitymetric_bioregion_clipped_nutrients.csv')) 

#J
df = pd.read_csv(J, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_biohab_metric_bioregion_clipped_nutrients.csv')) 

#K
df = pd.read_csv(K, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_monitoringlocations_bioregion_clipped_nutrients.csv')) 


#L
df = pd.read_csv(L, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_narrowresults_bioregion_clipped_nutrients.csv')) 

#M
df = pd.read_csv(M, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_physchemresults_bioregion_clipped_nutrients.csv'))

#N
df = pd.read_csv(N, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_resultsbiological_bioregion_clipped_nutrients.csv'))

#O
df = pd.read_csv(O, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df.stack().str.contains(kwstr).any(level=0)
df[mask].to_csv(os.path.join(outdir, 'SD_sitedata_bioregion_clipped_nutrients.csv'))
# Out:
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# ...

# %%
#select specific column

A="NE_narrowresults_bioregion_clipped.csv"
B="NE_physchem_bioregion_clipped.csv"
C="NE_resdetectqntlmt_bioregion_clipped.csv"
D="NE_resultsbiological_bioregion_clipped.csv"
E="SD_narrowresults_bioregion_clipped.csv"
F="SD_physchemresults_bioregion_clipped.csv"
G="SD_resultsbiological_bioregion_clipped.csv"


#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_general.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_general.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_general.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_general.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_general.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_general.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_general.csv'))
# Out:
# Ammonia|Nitrate/Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CharacteristicName'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#MAKE SURE IT SEPERATES 
with open(os.path.join(parameter, "misc.txt")) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
        content = [x.strip() for x in content] 
        df[df.stack().str.contains('|'.join(content)).any(level=0)]
        kwstr = '|'.join(content)
        print (kwstr)
# Out:
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll

# %%
#Now loop through General Parameters
from pathlib import Path

folder="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"


for file in Path(folder).glob('*.csv'):
    
    #Filter for any string containing Stephen's Parameters
    df = pd.read_csv(file, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

    with open(os.path.join(parameter, "misc.txt")) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
        content = [x.strip() for x in content] 
        df[df.stack().str.contains('|'.join(content)).any(level=0)]
        kwstr = '|'.join(content)
        for row in df: 
            df.stack().str.contains(kwstr)
            mask = df.stack().str.contains(kwstr).any(level=0)
            result = df[mask]
            result.to_csv(os.path.join(outdir, file.stem +'_misc.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-e483d4d7e1b2> in <module>
#      18         df[df.stack().str.contains('|'.join(content)).any(level=0)]
#      19         kwstr = '|'.join(content)
# ---> 20         print (kwstrt)
#      21
#      22         for row in df:
#
# NameError: name 'kwstrt' is not defined

# %%
##alternative plan:
#Now loop through General Parameters
from pathlib import Path

folder="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
    
#Filter for any string containing Stephen's Parameters
df = pd.read_csv('SD_narrowresults_bioregion_clipped.csv', sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content] 
    df[df.stack().str.contains('|'.join(content)).any(level=0)]
    kwstr = '|'.join(content) 
    df.stack().str.contains(kwstr)
    mask = df.stack().str.contains(kwstr).any(level=0)
    result = df[mask]
    result.to_csv(os.path.join(outdir, file.stem +'_misc.csv'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
#plot some results
