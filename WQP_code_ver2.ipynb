# %%
#select specific column
import os
import glob
import zipfile
import pandas as pd
from pathlib import Path

#change the working directory where your folders are stored
os.chdir('C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract')

A="NE_narrowresults_bioregion_clipped.csv"
B="NE_physchem_bioregion_clipped.csv"
C="NE_resdetectqntlmt_bioregion_clipped.csv"
D="NE_resultsbiological_bioregion_clipped.csv"
E="SD_narrowresults_bioregion_clipped.csv"
F="SD_physchemresults_bioregion_clipped.csv"
G="SD_resultsbiological_bioregion_clipped.csv"
H="SD_resdetectqntlmt_bioregion_clipped.csv"


#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_general.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_general.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_general.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_general.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_general.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_general.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_general.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "general.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_general.csv'))
# Out:
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity
# Instantaneous Discharge|UV absorbance|Barometric pressure|Gauge height|Dissolved Oxygen|pH|Specific Conductance|Temperature|Transparency|Turbidity

# %%
###################### INORGANICS ############################################33

#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_inorganics.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_inorganics.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_inorganics.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_inorganics.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_inorganics.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_inorganics.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_inorganics.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "inorganics.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_inorganics.csv'))
# Out:
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen
# Alkalinity|ANC|Carbonate|Bicarbonate|Chloride|Fluoride|Silica|Sulfate|Dissolved Oxygen

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_metals.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_metals.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_metals.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_metals.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_metals.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_metals.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_metals.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "metals.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_metals.csv'))
# Out:
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium
# Aluminum|Antimony|Arsenic|Barium|Beryllium|Boron|Cadmium|Chromium|Cobalt|Copper|Iron|Lead|Manganese|Molybdenum|Nickel|Selenium|Silver|Strontium|Uranium|Vanadium|Zinc|Calcium|Magnesium|Potassium|Sodium

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_misc.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_misc.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_misc.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_misc.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_misc.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_misc.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_misc.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "misc.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_misc.csv'))
# Out:
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll
# Carbon suspended|Inorganic Carbon|Organic Carbon|Chlorophyll

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_nutrients.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_nutrients.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_nutrients.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_nutrients.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_nutrients.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_nutrients.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_nutrients.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "nutrients.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_nutrients.csv'))
# Out:
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus
# Ammonia|Nitrate|Nitrite|Particulate Nitrogen|Orthophosphate|Phosphorus

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_orgsemivol.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_orgsemivol.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_orgsemivol.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_orgsemivol.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_orgsemivol.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_orgsemivol.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_orgsemivol.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgsemivol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_orgsemivol.csv'))
# Out:
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol
# Anthracene|Benzo(a)anthracene|Benzo(a)pyrene|Benzo(b)fluoranthene|Benzo(g,h,i)perylene|Benzo(k)fluoranthene|4-Bromophenylphenyl ether|Butylbenzylphthalate|Carbazole|4-Chloro-3-methylphenol|4-Chloroaniline|bis(2-Chloroethoxy) methane|bis(2-Chloroethyl) ether|bis(2-Chloroisopropyl) ether|2-Chloronaphthalene|2-Chlorophenol|4-Chlorophenylphenyl ether|Chrysene|Dibenz(a,h)anthracene|Dibenzofuran|1,2-Dichlorobenzene|1,3-Dichlorobenzene|1,4-Dichlorobenzene|3,3'-Dichlorobenzidine|2,4-Dichlorophenol|Diethylphthalate|2,4-Dimethylphenol|Dimethylphthalate|Di-n-butylphthalate|4,6-Dinitro-2-methylphenol|2,4-Dinitrophenol|2,4-Dinitrotoluene|2,6-Dinitrotoluene|Di-n-octylphthalate|1,2-Diphenylhydrazine|bis(2-Ethylhexyl) phthalate|Fluoranthene|Fluorene|Hexachloro-1,3-butadiene|Hexachlorobenzene|Hexachloroethane|Indeno(1,2,3-cd) pyrene|Isophorone|Acenaphthene|Acenaphthylene|1-Methylnaphthalene|2-Methylnaphthalene|2-Methylphenol|o-Cresol|3&4-Methylphenol|m&p Cresol|Naphthalene|2-Nitroaniline|3-Nitroaniline|4-Nitroaniline|Nitrobenzene|2-Nitrophenol|4-Nitrophenol|N-Nitrosodimethylamine|N-Nitroso-di-n-propylamine|N-Nitrosodiphenylamine|Pentachlorophenol|Phenanthrene|Phenol|Pyrene|1,2,4-Trichlorobenzene|2,4,5-Trichlorophenol|2,4,6-Trichlorophenol

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_orgvol.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_orgvol.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_orgvol.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_orgvol.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_orgvol.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_orgvol.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_orgvol.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "orgvol.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_orgvol.csv'))
# Out:
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride
# Acrolein|Acrylonitrile|Benzene|Bromodichloromethane|Bromoform|Bromomehtane|methyl bromide|Carbon tetrachloride|Chloroethane|2-Chloroehtylvinyl ether|Chloroform|Chloromethane|Dibromochloromethane|1,1-Dichloroethane|1,2-Dchloroethane|Trans-1,2-Dichloroethane|1,1-Dichloroethene|1,2-Dichloropropene|Ethyl Benzene|Methylene Chloride|dichloromethane|1,1,2,2-Tetrachloroethane|Tetrachloroethene|Toluene|1,1,1-Trichloroethane|1,1,2-Trichloroethane|Trichloroethene|Vinyl Chloride

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_PCB.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_PCB.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_PCB.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_PCB.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_PCB.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_PCB.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_PCB.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "PCB.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_PCB.csv'))
# Out:
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016
# PCB-1242|Aroclor 1242|PCB-1254|Aroclor 1254|PCB-1221|Aroclor 1221|PCB-1232|Aroclor 1232|PCB-1248|Aroclor 1248|PCB-1260|Aroclor 1260|PCB-1016|Aroclor 1016

# %%
#A
df = pd.read_csv(A, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"
parameter="C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/Paramlist"


with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_narrowresults_bioregion_clipped_pest.csv'))

#B
df = pd.read_csv(B, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_physchem_bioregion_clipped_pest.csv'))

#C
df = pd.read_csv(C, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resdetectqntlmt_bioregion_clipped_pest.csv'))

#D
df = pd.read_csv(D, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'NE_resultsbiological_bioregion_clipped_pest.csv'))

#E
df = pd.read_csv(E, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_narrowresults_bioregion_clipped_pest.csv'))

#F
df = pd.read_csv(F, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_physchemresults_bioregion_clipped_pest.csv'))

#G
df = pd.read_csv(G, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resultsbiological_bioregion_clipped_pest.csv'))

#H

df = pd.read_csv(H, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
outdir= "C:/Users/The Reckoning/Documents/CHEJ/WaterQualityData_2021/WQP_extract/export"

with open(os.path.join(parameter, "pest.txt")) as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 

df[df.stack().str.contains('|'.join(content)).any(level=0)]
kwstr = '|'.join(content)
print(kwstr)
df.stack().str.contains(kwstr)
mask = df[df['CharacteristicName'].str.contains(kwstr).any(level=0)]
mask.to_csv(os.path.join(outdir,'SD_resdetectqntlmt_bioregion_clipped_pest.csv'))
# Out:
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin

# %%
# Out:
# 2,6-Diethylaniline|Acetochlor|Alachlor|alpha-HCH|alpha-HCH-d6 (percent recovery)|Atrazine|Azinphos-methyl|Benfluralin|Butylate|Carbaryl|Carbofuran|Chlorpyrifos|CIAT|cis-Permethrin|Cyanazine|DCPA|Desulfinylfipronil|Desulfinylfipronil amide|Diazinon|Diazinon-d10 (percent recovery)|Dieldrin|Disulfoton|EPTC|Ethalfluralin|Ethoprop|Fipronil|Fipronil Sulfide|Fipronil Sulfone|Fonofos|Lindane|Linuron|Malathion|Methyl Parathion|Metolachlor|Metribuzin|Molinate|Naproamide|p,pâ€™-DDE|Parathion|Pebulate|Pendimethalin|Phorate|Prometon|Propachlor|Propanil|Propargite|Propyzamide|Simazine|Tebuthiuron|Terbacil|Terbufos|Thiobencarb|Triallate|Trifluralin
